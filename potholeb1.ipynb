# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical, image_dataset_from_directory
from tensorflow.keras import layers, models
import matplotlib.pyplot as plt
import os
import cv2
import imghdr
import numpy as np
from pathlib import Path

# %%
data = image_dataset_from_directory("drive/MyDrive/pothole_dataset",image_size =(240,240))
# Out:
# Found 5859 files belonging to 2 classes.

# %%
class_names = data.class_names
class_names
len(data)
# Out:
# 184

# %%
print(class_names)
# Out:
# ['pothole', 'road']

# %%
train_size = 0.8
len(data)*train_size
# Out:
# 147.20000000000002

# %%
train_data = data.take(147)
len(train_data)
# Out:
# 147

# %%
test_data = data.skip(147)
len(train_data)
# Out:
# 147

# %%
test_data=data.skip(147)
len(test_data)
# Out:
# 37

# %%
val_size = 0.1
len(data)*val_size
# Out:
# 18.400000000000002

# %%
val_data = test_data.take(18)
len(val_data)
# Out:
# 18

# %%
test_data = test_data.skip(18)
len(test_data)
# Out:
# 19

# %%
print(len(train_data))
print(len(test_data))
print(len(val_data))
# Out:
# 147
# 19
# 18

# %%
model = models.Sequential([
    Conv2D(32, kernel_size = (3,3), activation = "relu", input_shape = (240,240,3)),
    MaxPooling2D(2,2),
    Conv2D(64, kernel_size = (3,3), activation = "relu"),
    MaxPooling2D(2,2),
    Conv2D(64, kernel_size = (3,3), activation = "relu"),
    MaxPooling2D(2,2),
    Flatten(),
    Dense(64, activation = "relu"),
    Dense(3, activation = "softmax")
])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_3 (Conv2D)           (None, 238, 238, 32)      896
#
#  max_pooling2d_3 (MaxPoolin  (None, 119, 119, 32)      0
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 117, 117, 64)      18496
#
#  max_pooling2d_4 (MaxPoolin  (None, 58, 58, 64)        0
#  g2D)
#
#  conv2d_5 (Conv2D)           (None, 56, 56, 64)        36928
#
#  max_pooling2d_5 (MaxPoolin  (None, 28, 28, 64)        0
#  g2D)
#
#  flatten_1 (Flatten)         (None, 50176)             0
#
#  dense_2 (Dense)             (None, 64)                3211328
#
#  dense_3 (Dense)             (None, 3)                 195
#
# ...
# Total params: 3267843 (12.47 MB)
# Trainable params: 3267843 (12.47 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(
    optimizer = Adam(),
    loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits = False),
    metrics = ["accuracy"]
)

# %%
history = model.fit(
    train_data,
    verbose = 1,
    epochs = 1   #20
)
# Out:
# 147/147 [==============================] - 916s 6s/step - loss: 10.4085 - accuracy: 0.9088 - val_loss: 0.1193 - val_accuracy: 0.9583

# %%
model.save("drive/MyDrive/b1.h5")
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
